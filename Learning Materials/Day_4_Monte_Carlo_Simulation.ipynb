# %% [markdown]
# <a href="https://colab.research.google.com/github/Error-Nasim/Simulation-and-Modeling-Lab/blob/main/Learning%20Materials/Day_4_Monte_Carlo_Simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random  # to create random numbers

def estimate_pi(num_points):
    inside = 0  # how many points inside the circle

    for i in range(num_points):
        x = random.random()  # pick a random number from 0 to 1
        y = random.random()
        if x*x + y*y <= 1:      # x*x+y*y<=r*r inside circle
            inside += 1  # it's inside the circle

    pi = 4 * inside / num_points
    print("Estimated pi for", num_points, "points is:", pi)

# Try this with different number of points
estimate_pi(1000)
estimate_pi(5000)
estimate_pi(10000)
estimate_pi(50000)
estimate_pi(100000)
# Out:
# Estimated pi for 1000 points is: 3.068
# Estimated pi for 5000 points is: 3.156
# Estimated pi for 10000 points is: 3.1476
# Estimated pi for 50000 points is: 3.14136
# Estimated pi for 100000 points is: 3.14976

# %% [markdown]
# Student work: Estimate the probability of getting at least one 6 when rolling a die 10 times.

# %%
import random
def get_six(roll):
  ans=0
  terget=6
  for j in range(roll):
    rolls=random.randint(1,7)
    if rolls==terget:
      ans+=1
  print(f"Probabilty of Getting at least one 6 when rolling a die {roll} times: {ans/roll}")
get_six(10)
get_six(100)
get_six(1000)
get_six(10000)
get_six(100000)
get_six(1000000)
# Out:
# Probabilty of Getting at least one 6 when rolling a die 10 times: 0.1
# Probabilty of Getting at least one 6 when rolling a die 100 times: 0.13
# Probabilty of Getting at least one 6 when rolling a die 1000 times: 0.164
# Probabilty of Getting at least one 6 when rolling a die 10000 times: 0.1414
# Probabilty of Getting at least one 6 when rolling a die 100000 times: 0.14317
# Probabilty of Getting at least one 6 when rolling a die 1000000 times: 0.143205
